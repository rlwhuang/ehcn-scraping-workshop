# %% [markdown]
# ## Download the snapshots
# Now that we have the snapshots timestamp, we can download the snapshots from the Wayback Machine.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.support.wait import WebDriverWait
from pathlib import Path
import time

# %% [markdown]
# ### Load the data

# %%
########################
## Read URLs from a JSON file
########################

import json
URL_PATH = "urls_with_snapshots.json"

# INITIALIZE THE URL LIST
url_list = []

with open(URL_PATH, "r") as f:
    url_list = json.load(f)

print(f"Read {len(url_list)} URLs from {URL_PATH}")
print("First 5 URLs:")
print(url_list)
for url in url_list[:5]:
    print(url)
# Out:
# Read 20 URLs from urls_with_snapshots.json
# First 5 URLs:
# [{'id': '4da862f1', 'url': 'http://www.voicenet.com/~squeeze/contras.html', 'snapshots': [{'timestamp': 19961222204926, 'statuscode': 200, 'url': 'https://web.archive.org/web/19961222204926if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19970406223306, 'statuscode': 200, 'url': 'https://web.archive.org/web/19970406223306if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19970615113827, 'statuscode': 200, 'url': 'https://web.archive.org/web/19970615113827if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19970804051208, 'statuscode': 200, 'url': 'https://web.archive.org/web/19970804051208if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19991012124911, 'statuscode': 200, 'url': 'https://web.archive.org/web/19991012124911if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19991122034535, 'statuscode': 200, 'url': 'https://web.archive.org/web/19991122034535if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19991127111615, 'statuscode': 200, 'url': 'https://web.archive.org/web/19991127111615if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19991128184315, 'statuscode': 200, 'url': 'https://web.archive.org/web/19991128184315if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19991130074106, 'statuscode': 200, 'url': 'https://web.archive.org/web/19991130074106if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000304055004, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000304055004if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000308183445, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000308183445if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000414091954, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000414091954if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000419180441, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000419180441if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000420232447, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000420232447if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000520034647, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000520034647if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000526101746, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000526101746if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000608045525, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000608045525if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000613151855, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000613151855if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000618195321, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000618195321if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000815194708, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000815194708if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20001016035235, 'statuscode': 200, 'url': 'https://web.archive.org/web/20001016035235if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20001018040619, 'statuscode': 200, 'url': 'https://web.archive.org/web/20001018040619if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20001202174400, 'statuscode': 200, 'url': 'https://web.archive.org/web/20001202174400if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20010107122200, 'statuscode': 200, 'url': 'https://web.archive.org/web/20010107122200if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20010201165800, 'statuscode': 200, 'url': 'https://web.archive.org/web/20010201165800if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20010405183518, 'statuscode': 200, 'url': 'https://web.archive.org/web/20010405183518if_/http:// ...
# {'id': '4da862f1', 'url': 'http://www.voicenet.com/~squeeze/contras.html', 'snapshots': [{'timestamp': 19961222204926, 'statuscode': 200, 'url': 'https://web.archive.org/web/19961222204926if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19970406223306, 'statuscode': 200, 'url': 'https://web.archive.org/web/19970406223306if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19970615113827, 'statuscode': 200, 'url': 'https://web.archive.org/web/19970615113827if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19970804051208, 'statuscode': 200, 'url': 'https://web.archive.org/web/19970804051208if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19991012124911, 'statuscode': 200, 'url': 'https://web.archive.org/web/19991012124911if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19991122034535, 'statuscode': 200, 'url': 'https://web.archive.org/web/19991122034535if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19991127111615, 'statuscode': 200, 'url': 'https://web.archive.org/web/19991127111615if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19991128184315, 'statuscode': 200, 'url': 'https://web.archive.org/web/19991128184315if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19991130074106, 'statuscode': 200, 'url': 'https://web.archive.org/web/19991130074106if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000304055004, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000304055004if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000308183445, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000308183445if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000414091954, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000414091954if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000419180441, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000419180441if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000420232447, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000420232447if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000520034647, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000520034647if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000526101746, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000526101746if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000608045525, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000608045525if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000613151855, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000613151855if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000618195321, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000618195321if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000815194708, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000815194708if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20001016035235, 'statuscode': 200, 'url': 'https://web.archive.org/web/20001016035235if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20001018040619, 'statuscode': 200, 'url': 'https://web.archive.org/web/20001018040619if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20001202174400, 'statuscode': 200, 'url': 'https://web.archive.org/web/20001202174400if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20010107122200, 'statuscode': 200, 'url': 'https://web.archive.org/web/20010107122200if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20010201165800, 'statuscode': 200, 'url': 'https://web.archive.org/web/20010201165800if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20010405183518, 'statuscode': 200, 'url': 'https://web.archive.org/web/20010405183518if_/http://w ...
# {'id': '39856e66', 'url': 'http://www.mediagate.com', 'snapshots': [{'timestamp': 19981203120730, 'statuscode': 200, 'url': 'https://web.archive.org/web/19981203120730if_/http://www.mediagate.com'}, {'timestamp': 19981212030901, 'statuscode': 200, 'url': 'https://web.archive.org/web/19981212030901if_/http://www.mediagate.com'}, {'timestamp': 19990208014743, 'statuscode': 200, 'url': 'https://web.archive.org/web/19990208014743if_/http://www.mediagate.com'}, {'timestamp': 19990210114436, 'statuscode': 200, 'url': 'https://web.archive.org/web/19990210114436if_/http://www.mediagate.com'}, {'timestamp': 19990423041932, 'statuscode': 200, 'url': 'https://web.archive.org/web/19990423041932if_/http://www.mediagate.com'}, {'timestamp': 19991001203950, 'statuscode': 200, 'url': 'https://web.archive.org/web/19991001203950if_/http://www.mediagate.com'}, {'timestamp': 20000301024647, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000301024647if_/http://www.mediagate.com'}, {'timestamp': 20000511124935, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000511124935if_/http://www.mediagate.com'}, {'timestamp': 20000520071602, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000520071602if_/http://www.mediagate.com'}, {'timestamp': 20000610201533, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000610201533if_/http://www.mediagate.com'}, {'timestamp': 20000706212528, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000706212528if_/http://www.mediagate.com'}, {'timestamp': 20000706221741, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000706221741if_/http://www.mediagate.com'}, {'timestamp': 20000711075955, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000711075955if_/http://www.mediagate.com'}, {'timestamp': 20000815055446, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000815055446if_/http://www.mediagate.com'}, {'timestamp': 20001018024034, 'statuscode': 200, 'url': 'https://web.archive.org/web/20001018024034if_/http://www.mediagate.com'}, {'timestamp': 20001018165627, 'statuscode': 200, 'url': 'https://web.archive.org/web/20001
 'statuscode': 200, 'url': 'https://web.archive.org/web/19991001064630if_/http://www.ad-guide.com'}, {'timestamp': 19991013045719, 'statuscode': 200, 'url': 'https://web.archive.org/web/19991013045719if_/http://www.ad-guide.com'}, {'timestamp': 19991122002405, 'statuscode': 200, 'url': 'https://web.archive.org/web/19991122002405if_/http://www.ad-guide.com'}, {'timestamp': 20000301114347, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000301114347if_/http://www.ad-guide.com'}, {'timestamp': 20000303185447, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000303185447if_/http://www.ad-guide.com'}, {'timestamp': 20000311180308, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000311180308if_/http://www.ad-guide.com'}, {'timestamp': 20000510070812, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000510070812if_/http://www.ad-guide.com'}, {'timestamp': 20000511033028, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000511033028if_/http://www.ad-guide.com'}, {'timestamp': 20000519215610, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000519215610if_/http://www.ad-guide.com'}, {'timestamp': 20000520062459, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000520062459if_/http://www.ad-guide.com'}, {'timestamp': 20000616154330, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000616154330if_/http://www.ad-guide.com'}, {'timestamp': 20000621122746, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000621122746if_/http://www.ad-guide.com'}, {'timestamp': 20000621132808, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000621132808if_/http://www.ad-guide.com'}, {'timestamp': 20000815100417, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000815100417if_/http://www.ad-guide.com'}, {'timestamp': 20000827121801, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000827121801if_/http://www.ad-guide.com'}, {'timestamp': 20000930223724, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000930223724if_/http://www.ad-guide.com'}, {'timestamp': 20001018154050, 'statuscode': 200, 'url': 'https://web.archive.org/web/20001018154050if_/http://www.ad-guide.com'}, {'timestamp': 20001019025125, 'statuscode': 200, 'url': 'https://web.archive.org/web/20001019025125if_/http://www.ad-guide.com'}, {'timestamp': 20001204032300, 'statuscode': 200, 'url': 'https://web.archive.org/web/20001204032300if_/http://www.ad-guide.com'}, {'timestamp': 20010301235721, 'st ...

# %% [markdown]
# ### Iterate over the snapshots and download them
# We iterate over a list of website entries, where each entry contains a URL, an ID, and a collection of snapshots. For each entry, the script:
# - Creates a unique directory based on the entry's ID within a predefined base directory.
#   - We cannot use the URL as the directory name because it may contain characters that are not allowed in directory names, such as slashes and colons.
# - Iterates through each snapshot associated with this entry.
# - For every snapshot, it:
#   - Builds a directory for that specific snapshot based on its timestamp.
#   - Attempts to download the website snapshot from its URL, retrying up to three times in case of failure.
#   - Saves the downloaded HTML content into a file within the snapshot's directory.
#   - Pause between each snapshot download to manage request frequency, and extends this pause in case of download errors.

# %%
import os
import requests
import time

DATA_BASE_PATH = "data"
sleep_time_on_error = 5
sleep_time_per_snapshot = 1

total_entry_count = len(url_list)

for i, entry in enumerate(url_list):
    print(f"Processing entry: {i+1}/{total_entry_count}")
    url = entry["url"]
    id = entry["id"]
    snapshots =   entry["snapshots"]

    print(f"Processing URL: {url}")

    # create a directory for the URL
    url_path = os.path.join(DATA_BASE_PATH, id)
    os.makedirs(url_path, exist_ok=True)

    for snapshot in snapshots:
        snapshot_url = snapshot["url"]
        snapshot_timestamp = snapshot["timestamp"]
        # download the website snapshot from the url

        # make a directory for the snapshot
        snapshot_dir = os.path.join(url_path, str(snapshot_timestamp))
        os.makedirs(snapshot_dir, exist_ok=True)

        max_retries = 3

        for i in range(max_retries):
            try:
                response = requests.get(snapshot_url)
                print(f"Downloaded snapshot from {snapshot_url}")
                snapshot_path = os.path.join(snapshot_dir, "snapshot.html")
                with open(snapshot_path, "w") as f:
                    f.write(response.text)
                break

            except Exception as e:
                print(f"Error downloading snapshot: {e}")
                print(f"Sleeping for {sleep_time_on_error} seconds")
                time.sleep(sleep_time_on_error)
                continue

        print(f"Sleeping for {sleep_time_per_snapshot} seconds")
        time.sleep(sleep_time_per_snapshot)

# %% [markdown]
# ### Congrates! You have downloaded the snapshots.
# Check out your `data` folder to see the downloaded snapshots.
