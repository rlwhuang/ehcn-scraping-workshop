# %% [markdown]
# ## Fetch snapshots of urls on Wayback Machine
# - Load url from `.json` file
# - Fetch snapshots of urls on Wayback Machine

# %% [markdown]
# ### Load urls and id from `.json` file
#
# From the previous sketch, we have a `urls.json` file that contains the urls and their unique id. We will load the urls and their id from the file.
#
# ```python
# [{'id': "abcdef", 'url': 'https://www.example.com/page1'},
#  {'id': "abceef", 'url': 'https://www.example.com/page2'},
#  ...]
# ```

# %%
########################
## Read URLs from a JSON file
########################
import json
URL_PATH = "urls.json"

# INITIALIZE THE URL LIST
url_list = []

with open(URL_PATH, "r") as f:
    url_list = json.load(f)

print(f"Read {len(url_list)} URLs from {URL_PATH}")
print("First 5 URLs:")
print(url_list)
for url in url_list[:5]:
    print(url)
# Out:
# Read 20 URLs from urls.json
# First 5 URLs:
# [{'id': 'ada36222219fc23621b082fa89ff77d6', 'url': 'http://www.voicenet.com/~squeeze/contras.html'}, {'id': '19b3682f1c1d94e102ec232a35afdc0d', 'url': 'http://www.mediagate.com'}, {'id': '1e5e89dbb582367562a8073a3f1b1f77', 'url': 'http://www.artzone.gr'}, {'id': '714a9b6cc3b50a18cd8cc73c6baccf80', 'url': 'http://www.noqers.org'}, {'id': 'c779d2aa9338cfaace93c747189a02d7', 'url': 'http://www.ad-guide.com'}, {'id': '637bfdf647cceb27fa18ac2177b3ce48', 'url': 'http://www.dmplaza.com'}, {'id': 'f179aedafc625fee40a6b623be081729', 'url': 'http://www.bestwebs.com/vaudeville'}, {'id': '0d14a10ed63df4b397debece15ead3d3', 'url': 'http://www.homeportfolio.com'}, {'id': '9336d859af045fbed815b745311d47b3', 'url': 'http://www.nortelnetworks.com'}, {'id': '76b72e50a809a58a564f68c92bfc6db0', 'url': 'http://www.koshergrocer.com'}, {'id': 'ef4334af1f326f8f59bb715d23f9a593', 'url': 'http://www.pacificnet.net/~kites/ads/hang.ads.html'}, {'id': '9cedb6d87b11f118d6c7cbb310f2fc38', 'url': 'http://www.adam.com/diet_&_nutrition/diet_&_nutrition.htm'}, {'id': 'fc2e28ec654658527ef2a7f288d34d6f', 'url': 'http://www.womanlinks.com'}, {'id': 'b7cb05923b12ba564fed972f82a81025', 'url': 'http://www.cs.ualberta.ca/~chinook'}, {'id': '0568f30ae0fe42635a38d514c8b75f3b', 'url': 'http://www.casact.org'}, {'id': '467d95a781413a14edd7e2e8c6b38057', 'url': 'http://www.miserlymoms.com/MOMslinks.htm'}, {'id': 'b8cd1dbb5de62079fcae5da105201de1', 'url': 'http://e-math.ams.org'}, {'id': '6c3d9684badd045d34b612a60f79b6e5', 'url': 'http://www.surf-sun.com/worldbeaches.html'}, {'id': '3e3ede23a22c8ae8ffd5b0a4dc2a83ea', 'url': 'http://www.parentsoup.com/chat'}, {'id': '1667cf39278fd672424db9b983df0a22', 'url': 'http://www.iclei.org/efacts'}]
# {'id': 'ada36222219fc23621b082fa89ff77d6', 'url': 'http://www.voicenet.com/~squeeze/contras.html'}
# {'id': '19b3682f1c1d94e102ec232a35afdc0d', 'url': 'http://www.mediagate.com'}
# {'id': '1e5e89dbb582367562a8073a3f1b1f77', 'url': 'http://www.artzone.gr'}
# {'id': '714a9b6cc3b50a18cd8cc73c6baccf80', 'url': 'http://www.noqers.org'}
# {'id': 'c779d2aa9338cfaace93c747189a02d7', 'url': 'http://www.ad-guide.com'}

# %% [markdown]
# ### Fetch available snapshots from Wayback Machine
# Wayback Machine provides an API to fetch the available snapshots of a url, called the [Wayback CDX Server](https://archive.org/developers/wayback-cdx-server.html#basic-usage). By query this API programmatically, we can get the available snapshots of a url in the archive. Currently, these fields are available in the CDX Server:
# ```
# ["urlkey","timestamp","original","mimetype","statuscode","digest","length"]
# ```
#
# We will just focus on the `timestamp` field, which is the timestamp of when the snapshot was taken, and the `statuscode` field, which is the [HTTP status code](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status) of the snapshot.
# - With `url` and `timestamp`, we can construct the url of the snapshot, and scrape the content of the snapshot later.
# - With `statuscode`, we can filter out the snapshots that are not actually available on the Wayback Machine.

# %%
# requests is a library for making HTTP requests
# here we are just using it to construct a URL with parameters
import requests

# pandas is a powerful data manipulation library
# here we are using it to read the CSV response from the Wayback Machine
import pandas as pd

from time import sleep

from IPython.display import clear_output


# define the time range for the snapshots
from_time = "19960101"
to_time = "20051231"

def make_wm_cdx_url(url, from_time="19960101", to_time="20051231"):
    """
    Construct a URL to query the Wayback Machine CDX API
    for a given URL and time range
    """
    base_url = "https://web.archive.org/cdx/search/cdx"
    params = {
        "url": url,
        "from": from_time,
        "to": to_time,
    }

    # this will create a URL with the parameters
    # eg. https://web.archive.org/cdx/search/cdx?url=example.com&from=19960101&to=20051231
    url_with_params = requests.Request("GET", base_url, params=params).prepare().url
    return url_with_params


total_url_count = len(url_list)
sleep_time_on_error = 10
sleep_time_on_success = 1


for i, entry in enumerate(url_list):
    print(f"Processing URL {i+1}/{total_url_count}")

    url = entry["url"]
    id = entry["id"]
    print(f"Processing URL {url} with ID {id}")

    # create the URL with parameters
    wayback_cdx_url = make_wm_cdx_url(url)
    print(f"Wayback cdx url {wayback_cdx_url}")

    url_snapshots = []

    # we will try to fetch the URL multiple times in case of errors
    max_tries = 5

    for j in range(max_tries):
        # because we are sending requests to the internet, there are many things that can go wrong
        # we use a try/except block to catch any errors that occur
        # this is important because if one URL fails, we don't want the whole script to stop
        print(f"Try {j+1}/{max_tries}")
        try:
            # pandas fetch the CSV from the URL and parse it into a DataFrame
            # dataframe is the main data structure in pandas
            dataframe = pd.read_csv(
                wayback_cdx_url,
                names=[
                    "urlkey",
                    "timestamp",
                    "original",
                    "mimetype",
                    "statuscode",
                    "digest",
                    "length",
                ],
               sep="\s+"
            )

            # we convert the dataframe to a list of dictionaries
            snapshot_list = dataframe.to_dict("records")

            print(f"Found {len(snapshot_list)} snapshots for {url}")

            # only keep the timestamp and status code for each snapshot
            for snapshot in snapshot_list:
                url_snapshots.append(
                    {
                        "timestamp": snapshot["timestamp"],
                        "statuscode": snapshot["statuscode"],
                    }
                )
            break

        except Exception as e:
            print(f"Error reading {wayback_cdx_url}: {e}")
            print(f"Sleeping for {sleep_time_on_error} seconds")
            sleep(sleep_time_on_error)

            
    print(f"First 5 snapshots for {url}")
    for snapshot in url_snapshots[:5]:
        print(snapshot)
}, {'timestamp': 20030612152049, 'statuscode': 200}, {'timestamp': 20030725224217, 'statuscode': 200}, {'timestamp': 20030804061203, 'statuscode': 200}, {'timestamp': 20030930010602, 'statuscode': 200}, {'timestamp': 20031003000155, 'statuscode': 200}, {'timestamp': 20031021051623, 'statuscode': 200}, {'timestamp': 20031022235323, 'statuscode': 200}, {'timestamp': 20031027112514, 'statuscode': 200}, {'timestamp': 20031214065745, 'statuscode': 200}, {'timestamp': 20031217233606, 'statuscode': 200}, {'timestamp': 20031219134914, 'statuscode': 200}, {'timestamp': 20031223024019, 'statuscode': 200}, {'timestamp': 20031227110022, 'statuscode': 200}, {'timestamp': 20040101141131, 'statuscode': 200}, {'timestamp': 20040205194744, 'statuscode': 200}, {'timestamp': 20040321125137, 'statuscode': 200}, {'timestamp': 20040329142630, 'statuscode': 200}, {'timestamp': 20040520174155, 'statuscode': 200}, {'timestamp': 20040522130508, 'statuscode': 200}, {'timestamp': 20040607033206, 'statuscode': 200}, {'timestamp': 20040612112221, 'statuscode': 200}, {'timestamp': 20040616062009, 'statuscode': 200}, {'timesta ...

# %% [markdown]
# ### Process, filter and save available snapshots
# We want to filter out the snapshots that are not available on the Wayback Machine. We also want to aggregate the `timestamp` and `url` to retreve an accessible Wayback Machine url to the exact snapshot. We will save the available snapshots in a `.json` file.
#
# You might notice there is an `if_` in the Wayback Machine url. This is because having `if_` in the url will hide the default toolbar of the Wayback Machine, which is useful when we want to scrape the content of the snapshot.
#
# We also filters out the snapshots that are not available on the Wayback Machine. Based on the `statuscode`, we will only keep the snapshots that have `statuscode` of `200`.
#
# For this workshop, we are also sampling a smaller set of snapshots to scrape to save time. We will randomly take 10 snapshots from the available snapshots.
#
# ```python
# [{'id': "abcdef", 'url': 'https://www.example.com/page1', 'snapshots': [{'timestamp': '20210101000000', 'url': 'https://web.archive.org/web/20210101000000if_/https://www.example.com/page1'}]},
#  {'id': "abceef", 'url': 'https://www.example.com/page2', 'snapshots': [{'timestamp': '20210101000000', 'url': 'https://web.archive.org/web/20210101000000if_/https://www.example.com/page2'}]},
#  ...]
# ```

# %%
import random

url_with_snapshots_path = "urls_with_snapshots.json"
print(url_list)


new_url_list = []
snapshot_sample_size = 10

#
for entry in url_list:
    snapshots = entry["snapshots"]

    # only keep the snapshots with status code 200
    available_snapshots = []

    # only keep the snapshots with status code 200
    for snapshot in snapshots:
        if snapshot["statuscode"] == 200:
            # construct the URL to the snapshot
            snapshot_url = f"https://web.archive.org/web/{snapshot['timestamp']}if_/{entry['url']}"
            new_snapshot = {
                "timestamp": snapshot["timestamp"],
                "statuscode": snapshot["statuscode"],
                "url": snapshot_url,
            }
            available_snapshots.append(new_snapshot)

    # if there are no snapshots, we don't need to keep this URL
    if len(available_snapshots) == 0:
        continue
    
    
    # randomly sample 10 snapshots
    # because scraping all snapshots can be slow
    available_snapshots = random.sample(available_snapshots, min(snapshot_sample_size, len(available_snapshots)))

    new_entry = {
        "url": entry["url"],
        "id": entry["id"],
        "snapshots": available_snapshots
    }
    new_url_list.append(new_entry)



print(f"Kept {len(new_url_list)} URLs with snapshots")
scode': 302}, {'timestamp': 20040201214818, 'statuscode': 302}, {'timestamp': 20040607194701, 'statuscode': 200}, {'timestamp': 20040710152641, 'statuscode': 200}, {'timestamp': 20040722202211, 'statuscode': 200}, {'timestamp': 20040812025702, 'statuscode': 200}, {'timestamp': 20040815084354, 'statuscode': 200}, {'timestamp': 20041010035342, 'statuscode': 200}, {'timestamp': 20041206235552, 'statuscode': 200}, {'timestamp': 20050108095028, 'statuscode': 200}, {'timestamp': 20050205162008, 'statuscode': 200}, {'timestamp': 20050212130408, 'statuscode': 200}, {'timestamp': 20050405173139, 'statuscode': 200}, {'timestamp': 20050614002720, 'statuscode': 200}, {'timestamp': 20051230130313, 'statuscode': 404}]}, {'id': '19b3682f1c1d94e102ec232a35afdc0d', 'url': 'http://www.mediagate.com', 'snapshots': [{'timestamp': 19981203120730, 'statuscode': 200}, {'timestamp': 19981212030901, 'statuscode': 200}, {'timestamp': 19990208014743, 'statuscode': 200}, {'timestamp': 19990210114436, 'statuscode': 200}, {'timestamp': 19990423041932, 'statuscode': 200}, {'timestamp': 19991001203950, 'statuscode': 200}, {'timestamp': 20000301024647, 'statuscode' ...
# Kept 20 URLs with snapshots
# First 5 entries:
# {'url': 'http://www.voicenet.com/~squeeze/contras.html', 'id': 'ada36222219fc23621b082fa89ff77d6', 'snapshots': [{'timestamp': 20000815194708, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000815194708if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19961222204926, 'statuscode': 200, 'url': 'https://web.archive.org/web/19961222204926if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000419180441, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000419180441if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19970615113827, 'statuscode': 200, 'url': 'https://web.archive.org/web/19970615113827if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20010107122200, 'statuscode': 200, 'url': 'https://web.archive.org/web/20010107122200if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 19991127111615, 'statuscode': 200, 'url': 'https://web.archive.org/web/19991127111615if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20050405173139, 'statuscode': 200, 'url': 'https://web.archive.org/web/20050405173139if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000308183445, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000308183445if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20041206235552, 'statuscode': 200, 'url': 'https://web.archive.org/web/20041206235552if_/http://www.voicenet.com/~squeeze/contras.html'}, {'timestamp': 20000304055004, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000304055004if_/http://www.voicenet.com/~squeeze/contras.html'}]}
# {'url': 'http://www.mediagate.com', 'id': '19b3682f1c1d94e102ec232a35afdc0d', 'snapshots': [{'timestamp': 20040730002220, 'statuscode': 200, 'url': 'https://web.archive.org/web/20040730002220if_/http://www.mediagate.com'}, {'timestamp': 20030329142912, 'statuscode': 200, 'url': 'https://web.archive.org/web/20030329142912if_/http://www.mediagate.com'}, {'timestamp': 20030926023153, 'statuscode': 200, 'url': 'https://web.archive.org/web/20030926023153if_/http://www.mediagate.com'}, {'timestamp': 20040728152942, 'statuscode': 200, 'url': 'https://web.archive.org/web/20040728152942if_/http://www.mediagate.com'}, {'timestamp': 20050831153911, 'statuscode': 200, 'url': 'https://web.archive.org/web/20050831153911if_/http://www.mediagate.com'}, {'timestamp': 20050919055859, 'statuscode': 200, 'url': 'https://web.archive.org/web/20050919055859if_/http://www.mediagate.com'}, {'timestamp': 20000301024647, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000301024647if_/http://www.mediagate.com'}, {'timestamp': 19981212030901, 'statuscode': 200, 'url': 'https://web.archive.org/web/19981212030901if_/http://www.mediagate.com'}, {'timestamp': 20020923025003, 'statuscode': 200, 'url': 'https://web.archive.org/web/20020923025003if_/http://www.mediagate.com'}, {'timestamp': 20051211100623, 'statuscode': 200, 'url': 'https://web.archive.org/web/20051211100623if_/http://www.mediagate.com'}]}
# {'url': 'http://www.artzone.gr', 'id': '1e5e89dbb582367562a8073a3f1b1f77', 'snapshots': [{'timestamp': 20020528103931, 'statuscode': 200, 'url': 'https://web.archive.org/web/20020528103931if_/http://www.artzone.gr'}, {'timestamp': 20020808140811, 'statuscode': 200, 'url': 'https://web.archive.org/web/20020808140811if_/http://www.artzone.gr'}, {'timestamp': 20010404230605, 'statuscode': 200, 'url': 'https://web.archive.org/web/20010404230605if_/http://www.artzone.gr'}, {'timestamp': 20010302030101, 'statuscode': 200, 'url': 'https://web.archive.org/web/20010302030101if_/http://www.artzone.gr'}, {'timestamp': 20020802072617, 'statuscode': 200, 'url': 'https://web.archive.org/web/20020802072617if_/http://www.artzone.gr'}, {'timestamp': 20010703013803, 'statuscode': 200, 'url': 'https://web.archive.org/web/20010703013803if_/http://www.artzone.gr'}, {'timestamp': 19990428220137, 'statuscode': 200, 'url': 'https://web.archive.org/web/19990428220137if_/http://www.artzone.gr'}, {'timestamp': 20000519225604, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000519225604if_/http://www.artzone.gr'}, {'timestamp': 20000303082536, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000303082536if_/http://www.artzone.gr'}, {'timestamp': 20020124050119, 'statuscode': 200, 'url': 'https://web.archive.org/web/20020124050119if_/http://www.artzone.gr'}]}
# {'url': 'http://www.noqers.org', 'id': '714a9b6cc3b50a18cd8cc73c6baccf80', 'snapshots': [{'timestamp': 20040827002624, 'statuscode': 200, 'url': 'https://web.archive.org/web/20040827002624if_/http://www.noqers.org'}, {'timestamp': 19990427105931, 'statuscode': 200, 'url': 'https://web.archive.org/web/19990427105931if_/http://www.noqers.org'}, {'timestamp': 20010202133800, 'statuscode': 200, 'url': 'https://web.archive.org/web/20010202133800if_/http://www.noqers.org'}, {'timestamp': 19970220112530, 'statuscode': 200, 'url': 'https://web.archive.org/web/19970220112530if_/http://www.noqers.org'}, {'timestamp': 19961230073729, 'statuscode': 200, 'url': 'https://web.archive.org/web/19961230073729if_/http://www.noqers.org'}, {'timestamp': 19971022015749, 'statuscode': 200, 'url': 'https://web.archive.org/web/19971022015749if_/http://www.noqers.org'}, {'timestamp': 20001017163359, 'statuscode': 200, 'url': 'https://web.archive.org/web/20001017163359if_/http://www.noqers.org'}, {'timestamp': 19990208015218, 'statuscode': 200, 'url': 'https://web.archive.org/web/19990208015218if_/http://www.noqers.org'}, {'timestamp': 20030326122236, 'statuscode': 200, 'url': 'https://web.archive.org/web/20030326122236if_/http://www.noqers.org'}, {'timestamp': 20020602090726, 'statuscode': 200, 'url': 'https://web.archive.org/web/20020602090726if_/http://www.noqers.org'}]}
# {'url': 'http://www.ad-guide.com', 'id': 'c779d2aa9338cfaace93c747189a02d7', 'snapshots': [{'timestamp': 19990429080216, 'statuscode': 200, 'url': 'https://web.archive.org/web/19990429080216if_/http://www.ad-guide.com'}, {'timestamp': 20040924101517, 'statuscode': 200, 'url': 'https://web.archive.org/web/20040924101517if_/http://www.ad-guide.com'}, {'timestamp': 20040329142630, 'statuscode': 200, 'url': 'https://web.archive.org/web/20040329142630if_/http://www.ad-guide.com'}, {'timestamp': 20031021051623, 'statuscode': 200, 'url': 'https://web.archive.org/web/20031021051623if_/http://www.ad-guide.com'}, {'timestamp': 20000303185447, 'statuscode': 200, 'url': 'https://web.archive.org/web/20000303185447if_/http://www.ad-guide.com'}, {'timestamp': 20040926055904, 'statuscode': 200, 'url': 'https://web.archive.org/web/20040926055904if_/http://www.ad-guide.com'}, {'timestamp': 20040824061537, 'statuscode': 200, 'url': 'https://web.archive.org/web/20040824061537if_/http://www.ad-guide.com'}, {'timestamp': 20051224153710, 'statuscode': 200, 'url': 'https://web.archive.org/web/20051224153710if_/http://www.ad-guide.com'}, {'timestamp': 20041024032724, 'statuscode': 200, 'url': 'https://web.archive.org/web/20041024032724if_/http://www.ad-guide.com'}, {'timestamp': 20040205194744, 'statuscode': 200, 'url': 'https://web.archive.org/web/20040205194744if_/http://www.ad-guide.com'}]}
# Writing URLs with snapshots to urls_with_snapshots.json
